# %%
import pandas as pd
df_ano2004 = pd.read_stata(r"C:\Users\El economista\Documents\GitHub\-BigDataUBA-Grupo-25\TPs\TP 2\EPH 2004\Individual_t104.dta")

# %%
df_ano2024 = pd.read_stata(r"C:\Users\El economista\Documents\GitHub\-BigDataUBA-Grupo-25\TPs\TP 2\EPH_usu_1er_Trim_2024_xlsx\usu_individual_T124.dta")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar tu DataFrame (df_ano2024 en este caso)
df_corr = df_ano2024[["CH04", "CH06", "CH07", "CH08", "NIVEL_ED", "ESTADO", "CAT_INAC", "IPCF"]].corr()

# Crear el mapa de calor
plt.figure(figsize=(8, 6))
sns.heatmap(df_corr, annot=True, cmap="coolwarm", fmt=".2f")

# Mostrar el gráfico
plt.title("Matriz de Correlación año 2024")
plt.show()

# %%
# Cargar tu DataFrame (df_ano2024 en este caso)
df_corr = df_ano2004[["ch04", "ch06", "ch07", "ch08", "nivel_ed", "estado", "cat_inac", "ipcf"]].corr()

# Crear el mapa de calor
plt.figure(figsize=(8, 6))
sns.heatmap(df_corr, annot=True, cmap="coolwarm", fmt=".2f")

# Mostrar el gráfico
plt.title("Matriz de Correlación año 2004")
plt.show()
